# %%
<?php
use Illuminate\Support\Str;

Str::createUuidsUsing(function () {
    return new class {
        public function toString() {
            return 'mismatch-uuid-1234';
        }
        public function __toString() {
            return 'mismatch-uuid-1234';
        }
    };
});

echo Str::uuid()->toString();
